# %%
from bs4 import BeautifulSoup as bs
import requests
import lxml
from datetime import date

# %%
web1='https://www.mining.com/'
web2='https://www.renewableenergyworld.com/#gref'
web3='https://www.miningweekly.com/page/graphite'
web4='https://www.miningweekly.com/page/lithium'
web5='https://www.miningweekly.com/page/rare-earth-minerals'
web6='https://www.miningweekly.com/page/vanadium'
web7='https://www.theassay.com/news-2/'
web8='https://resourceworld.com/category/resources/cobalt/'
web9='https://resourceworld.com/category/resources/graphite/'
web10='https://resourceworld.com/category/resources/lithium/'
web11='https://resourceworld.com/category/resources/nickel/'
web12='https://resourceworld.com/category/resources/vanadium/'

# %%
html_text=requests.get(web1).text
soup=bs(html_text,'lxml')
articles=soup.find_all('div',class_='col-lg-8')
for article in articles:
        article_link=article.a['href']
        article_title=article.h3.text
        published_date=article.find('div',class_='post-meta').text

        print(f'''
Article Title:{article_title}\n
Article Link: {article_link}\n
Published_date: {published_date}\n
''')

        print('')
# Out:
# Article Title:
#
# A giant copper union joins push for bigger state role in Chile
#
#
# Article Link: https://www.mining.com/web/a-giant-copper-union-joins-push-for-bigger-state-role-in-chile/
#
# Published_date:
# June 18, 2021 | 1:01 pm
#
#
#
#
# Article Title:
#
# Taseko shakes management up as top bosses to retire
#
#
# Article Link: https://www.mining.com/taseko-shakes-management-up-as-top-bosses-to-retire/
#
# Published_date:
# June 18, 2021 | 7:38 am
#
#
#
#
# Article Title:
#
# Home: Metals boom sees the return of physically-backed funds
#
#
# Article Link: https://www.mining.com/web/home-metals-boom-sees-the-return-of-physically-backed-funds/
#
# Published_date:
# June 18, 2021 | 7:43 am
#
#
#
#
# Article Title:
#
# Wood Mackenzie boosts battery metals expertise with Roskill buy
#
#
# Article Link: https://www.mining.com/wood-mackenzie-boosts-battery-metals-expertise-with-roskill-buy/
#
# Published_date:
# June 18, 2021 | 3:43 am
#
#
#
#
# Article Title:
#
# ...

# %%
html_text=requests.get(web1).text
soup=bs(html_text,'lxml')
articles_1=soup.find_all('div',class_='col-lg-6.pb-3')
for article in articles_1:
        article_link=article.a['href']
        article_title=article.h3.text
        published_date=article.find('div',class_='post-meta').text

        print(f'''
Article Title:{article_title}\n
Article Link: {article_link}\n
Published_date: {published_date}\n
''')

        print('')

# %%
print(html_text)
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
#
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1">
# <link rel="apple-touch-icon" sizes="57x57" href="https://www.mining.com/wp-content/themes/miningdotcom/images/favicon/apple-icon-57x57.png">
# <link rel="apple-touch-icon" sizes="60x60" href="https://www.mining.com/wp-content/themes/miningdotcom/images/favicon/apple-icon-60x60.png">
# <link rel="apple-touch-icon" sizes="72x72" href="https://www.mining.com/wp-content/themes/miningdotcom/images/favicon/apple-icon-72x72.png">
# <link rel="apple-touch-icon" sizes="76x76" href="https://www.mining.com/wp-content/themes/miningdotcom/images/favicon/apple-icon-76x76.png">
# <link rel="apple-touch-icon" sizes="114x114" href="https://www.mining.com/wp-content/themes/miningdotcom/images/favicon/apple-icon-114x114.png">
# ...
